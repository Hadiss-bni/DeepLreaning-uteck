# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadiss-bni/DeepLreaning-UtechAcademy/blob/master/Homework_series1_N3_fashionmnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load dataset
(train_images, train_lables),(test_images,test_lables)=fashion_mnist.load_data()

# %%
num_of_classes = np.unique(train_lables).shape[0]
print('number of classes =',num_of_classes)
# Out:
# number of classes = 10

# %%
plt.imshow(train_image[10])
plt.figure()
plt.imshow(train_image[100])
plt.figure()
plt.imshow(train_image[1000])
plt.figure()
plt.imshow(train_image[10000])

# %%
print(type(train_images))
train_images.shape
# Out:
# <class 'numpy.ndarray'>
# (60000, 28, 28)

# %%
# Preprocess input data
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images,train_lables, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.9300 - accuracy: 0.6184
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.7369 - accuracy: 0.7537
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.7047 - accuracy: 0.7761
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6866 - accuracy: 0.7934
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6728 - accuracy: 0.8064
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6622 - accuracy: 0.8141
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6538 - accuracy: 0.8218
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6471 - accuracy: 0.8272
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6416 - accuracy: 0.8319
# Epoch 10/10
# ...
